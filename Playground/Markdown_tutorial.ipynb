# %% [markdown]
# # Types of text
#
#
# # Header 1
#
# ## Header 2
#
# ### Header 3
#
#
# _italic 1_
# *italic 2*
# __bold 1__
# **bold 2 **
#
# Writting something with a single newline here.
# BUt the text continues.

# %% [markdown]
# * And then we have lists
# * Or an itemizer.
#
#
#
# 1. But we can do the enumerater too
# 2. With out too much trouble

# %% [markdown]
# [It is possible to include hyperlinks](https://www.example.com)

# %% [markdown]
# Inline code uses single backticks: `foo()`, and code blocks use triple backticks:
# ```
# bar()
# ```
# Or can be indented by 4 spaces:
#
#     foo()

# %% [markdown]
# And finally, adding images is easy:
#
# Can be done via an internet URL or by "Edit/insert Image".
# ![JandJ.jpg](attachment:JandJ.jpg)
